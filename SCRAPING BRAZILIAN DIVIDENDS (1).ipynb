# %%
### SCRAPING BRAZILIAN DIVIDENDS         ## FUNDS

# %%
# LIBRARIES
import tabula
import PyPDF2
import csv
import os
import pandas as ps
import numpy as np

# %%
# Acessing directory
os.chdir("C:\\Users\\aline\\OneDrive\\Área de Trabalho\\Code")
#os.listdir()

# %%
# Accessing Link list 

csv_data = ps.read_csv('SAMPLE_COTISTAS.csv')

links = ps.DataFrame(csv_data, columns=['LINK'])

# %%
import os
os.environ['R_HOME'] = 'C:\\Users\\aline\\anaconda3\\envs\\r-tutorial\\Lib\\R'

# %%
# %load_ext rpy2.ipython 
# Source : https://www.askpython.com/python/examples/use-r-and-python-in-the-same-notebook#:~:text=To%20use%20R%20and%20python%20simultaneously%20in%20the%20same%20notebook,activate%20the%20rpy2%20package%20first.&text=rpy2%20is%20a%20high%2Dlevel,NumPy%20and%20pandas%20data%20structures.
#https://stackoverflow.com/questions/68031659/using-rpy2-in-jupyter-notebook-but-there-is-no-output-error-in-withvisible
# Out:
# C:\Users\aline\anaconda3\lib\site-packages\rpy2\robjects\packages.py:366: UserWarning: The symbol 'quartz' is not in this R namespace/package.
#   warnings.warn(

# %%
# %%R -i links
# # open links, screenshot, save  as pdf on your local directory
# #install.packages("webshot")
#
# library(webshot)
#
#
# for (url in links) {
#   webshot(url, file = paste(as.character(seq_len(length(url))),".pdf",sep=""),vwidth = 500,vheight = 500)
#     }
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-6-357bc464ba59> in <module>
# ----> 1 get_ipython().run_cell_magic('R', '-i links', '# open links, screenshot, save  as pdf on your local directory\n#install.packages("webshot")\n\nlibrary(webshot)\n\n\nfor (url in links) {\n  webshot(url, file = paste(as.character(seq_len(length(url))),".pdf",sep=""),vwidth = 500,vheight = 500)\n    }\n')
#
# ~\anaconda3\lib\site-packages\IPython\core\interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2397             with self.builtin_trap:
#    2398                 args = (magic_arg_s, cell)
# -> 2399                 result = fn(*args, **kwargs)
#    2400             return result
#    2401
#
# ~\anaconda3\lib\site-packages\decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# ~\anaconda3\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~\anaconda3\lib\site-packages\rpy2\ipython\rmagic.py in R(self, line, cell, local_ns)
#     802             # and "png" (else it's None)
#     803             if tmpd:
# --> 804                 rmtree(tmpd)
#     805
#     806         if args.output:
#
# ~\anaconda3\lib\shutil.py in rmtree(path, ignore_errors, onerror)
#     738             # can't continue even if onerror hook returns
#     739             return
# --> 740         return _rmtree_unsafe(path, onerror)
#     741
#     742 # Allow introspection of whether or not the hardening against symlink
#
# ~\anaconda3\lib\shutil.py in _rmtree_unsafe(path, onerror)
#     616                 os.unlink(fullname)
#     617             except OSError:
# --> 618                 onerror(os.unlink, fullname, sys.exc_info())
#     619     try:
#     620         os.rmdir(path)
#
# ~\anaconda3\lib\shutil.py in _rmtree_unsafe(path, onerror)
#     614         else:
#     615             try:
# --> 616                 os.unlink(fullname)
#     617             except OSError:
#     618                 onerror(os.unlink, fullname, sys.exc_info())
#
# PermissionError: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\aline\\AppData\\Local\\Temp\\tmpj45hphv_\\Rplots001.png'

# %%
#Import pdfs as tables

dividends = ps.DataFrame()
div = ps.DataFrame()

pdf_folder = "C:\\Users\\aline\\OneDrive\\Área de Trabalho\\Code"  
paths = [fn for fn in os.listdir(pdf_folder) if fn.endswith('.pdf')]
    
for path in paths:
    dividends = dividends.append(tabula.read_pdf(path, pages = 'all', pandas_options={'header': None}, multiple_tables=True)[1:])

# %%
# DATA CLEANING
ps.set_option('display.max_rows', None) #see all rows

div1 = dividends.drop(dividends.columns[[1, 2, 3]], axis=1)  # DROP COLUMNS 1,2,3


div1.columns = ["Data", "Rendimento", "Amortizacao"] # rename columns

div2 = div1.replace("Rendimento",np.nan)  # DELETING "RENDIMENTO"
div3 = div2.replace("Amortização",np.nan) # DELETING "AMORTIZACAO"

div4 = div3.dropna(how='all') #drop rolls with all NAN

div5= div4.drop(4, axis=0) # droping row 4 "ATO SOCIETARIO"

div5['Data'] = div5['Data'].replace(np.nan, "Tipo de Amortizacao")
# Out:
# <ipython-input-47-1e2c813e8e3f>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   div5['Data'] = div5['Data'].replace(np.nan, "Tipo de Amortizacao")
#                                                 Data   Rendimento  \
# 2                          Código ISIN: BRXPMLCTF000          NaN
# 5  Data-base (último dia de negociação “com” dire...   16/09/2022
# 6                     Valor do provento (R$/unidade)         0,73
# 7                                  Data do pagamento   23/09/2022
# 8                              Período de referência  Agosto-2022
# 9                           Rendimento isento de IR*          Sim
# 2                          Código ISIN: BRIBFFCTF007          NaN
# 3                                Tipo de Amortizacao          NaN
# 5  Data-base (último dia de negociação “com” dire...          NaN
# 6                     Valor do provento (R$/unidade)          NaN
# 7                                  Data do pagamento          NaN
# 8                              Período de referência          NaN
# 9                           Rendimento isento de IR*          NaN
# 2                          Código ISIN: BRXPINCTF004          NaN
# 5  Data-base (último dia de negociação “com” dire...   16/09/2022
# 6                     Valor do provento (R$/unidade)         0,62
# 7                                  Data do pagamento   23/09/2022
# 8                              Período de referência   31/08/2022
# 9                           Rendimento isento de IR*          Sim
# 2                          Código ISIN: BRFCFLCTF009          NaN
# 5  Data-base (último dia de negociação “com” dire...   16/09/2022
# 6                     Valor do provento (R$/unidade)  0,874307201
# 7                                  Data do pagamento   23/09/2022
# 8                              Período de referência  Agosto-2022
# 9                           Rendimento isento de IR*          Sim
# 2                          Código ISIN: BRBPMLCTF006          NaN
# 5  Data-base (último dia de negociação “com” dire...   16/09/2022
# 6                     Valor do provento (R$/unidade)          0,3
# 7                                  Data do pagamento   23/09/2022
# 8                              Período de referência   Julho-2022
# 9                           Rendimento isento de IR*          Sim
# 2                          Código ISIN: BRRDPDCTF008          NaN
# 3                                Tipo de Amortizacao          NaN
# 5  Data-base (último dia de negociação “com” dire...   28/02/2023
# 6                     Valor do provento (R$/unidade)         0,37
# 7                                  Data do pagamento   14/03/2023
# 8                              Período de referência    Fevereiro
# 9                           Rendimento isento de IR*          Sim
# 2                          Código ISIN: BRARRICTF009          NaN
# 5  Data-base (último dia de negociação “com” dire...   28/02/2023
# 6                     Valor do provento (R$/unidade)         0,07
# 7                                  Data do pagamento   07/03/2023
# 8                              Período de referência    FEVEREIRO
# 9                           Rendimento isento de IR*          Sim
# 2                          Código ISIN: BRARRIR12M19          NaN
# 5  Data-base (último dia de negociação “com” dire...   28/02/2023
# 6                     Valor do provento (R$/unidade)         0,04
# 7                                  Data do pagamento   07/03/2023
# 8                              Período de referência    FEVEREIRO
# 9                           Rendimento isento de IR*          Sim
#
#     Amortizacao
# 2           NaN
# 5           NaN
# 6           NaN
# 7           NaN
# 8           NaN
# 9           NaN
# 2           NaN
# 3       (Total)
# 5    16/09/2022
# 6  14,792522495
# 7    28/09/2022
# 8   Agosto-2022
# 9           NaN
# 2           NaN
# 5           NaN
# 6           NaN
# 7           NaN
# 8           NaN
# 9           NaN
# 2           NaN
# 5           NaN
# 6           NaN
# 7           NaN
# 8           NaN
# 9           NaN
# 2           NaN
# 5           NaN
# 6           NaN
# 7           NaN
# 8           NaN
# 9           NaN
# 2           NaN
# 3     (Parcial)
# 5    28/02/2023
# 6   1,824279249
# 7    14/03/2023
# 8     Fevereiro
# 9           NaN
# 2           NaN
# 5           NaN
# 6           NaN
# 7           NaN
# 8           NaN
# 9           NaN
# 2           NaN
# 5           NaN
# 6           NaN
# 7           NaN
# 8           NaN
# 9           NaN

# %%
#RENAMING COLUMNS
div6 =div5.transpose()

div7 = div6.rename(columns={div6.columns[0]: 'ISIN',
                            div6.columns[1]: 'Data Base',
                            div6.columns[2]: 'Valor',
                            div6.columns[3]: 'Data de Pagamento',
                            div6.columns[4]: 'Periodo de Referencia',
                            div6.columns[5]: 'Isento IR',
                            div6.columns[7]: 'Tipo Amortizacao'})

#COPY ISIN TO EMPTY CELLS BELOW
div8 = div7['ISIN'].fillna(method='ffill')
div7['ISIN']=div8    

#REMOVING FIRST ROW
div9 = div7.tail(-1)
div9["Tipo Amortizacao"]
# Out:
#             Tipo Amortizacao Tipo Amortizacao
# Rendimento               NaN              NaN
# Amortizacao          (Total)        (Parcial)

# %%
ISIN = div9['ISIN'].stack(dropna=False).reset_index()
Tipo_Amortizacao = div9['Tipo Amortizacao'].stack(dropna=False).reset_index(drop=True)
Isento_IR = div9['Isento IR'].stack(dropna=False).reset_index(drop=True)
Valor = div9['Valor'].stack(dropna=False).reset_index(drop=True)
Data_Pagamento = div9['Data de Pagamento'].stack(dropna=False).reset_index(drop=True)
Data_Base = div9['Data Base'].stack(dropna=False).reset_index(drop=True)
Periodo_Referencia = div9['Periodo de Referencia'].stack(dropna=False).reset_index(drop=True)


combined = ps.concat([ISIN,Tipo_Amortizacao,Isento_IR,Valor,Data_Pagamento,Data_Base,Periodo_Referencia],axis=1)
combined.reset_index(drop=True)
# Out:
#         level_0 level_1                          0          0    1  \
# 0    Rendimento    ISIN  Código ISIN: BRXPMLCTF000        NaN  Sim
# 1    Rendimento    ISIN  Código ISIN: BRIBFFCTF007        NaN  NaN
# 2    Rendimento    ISIN  Código ISIN: BRXPINCTF004    (Total)  Sim
# 3    Rendimento    ISIN  Código ISIN: BRFCFLCTF009  (Parcial)  Sim
# 4    Rendimento    ISIN  Código ISIN: BRBPMLCTF006        NaN  Sim
# 5    Rendimento    ISIN  Código ISIN: BRRDPDCTF008        NaN  Sim
# 6    Rendimento    ISIN  Código ISIN: BRARRICTF009        NaN  Sim
# 7    Rendimento    ISIN  Código ISIN: BRARRIR12M19        NaN  Sim
# 8   Amortizacao    ISIN  Código ISIN: BRXPMLCTF000        NaN  NaN
# 9   Amortizacao    ISIN  Código ISIN: BRIBFFCTF007        NaN  NaN
# 10  Amortizacao    ISIN  Código ISIN: BRXPINCTF004        NaN  NaN
# 11  Amortizacao    ISIN  Código ISIN: BRFCFLCTF009        NaN  NaN
# 12  Amortizacao    ISIN  Código ISIN: BRBPMLCTF006        NaN  NaN
# 13  Amortizacao    ISIN  Código ISIN: BRRDPDCTF008        NaN  NaN
# 14  Amortizacao    ISIN  Código ISIN: BRARRICTF009        NaN  NaN
# 15  Amortizacao    ISIN  Código ISIN: BRARRIR12M19        NaN  NaN
#
#                2           3           4            5
# 0           0,73  23/09/2022  16/09/2022  Agosto-2022
# 1            NaN         NaN         NaN          NaN
# 2           0,62  23/09/2022  16/09/2022   31/08/2022
# 3    0,874307201  23/09/2022  16/09/2022  Agosto-2022
# 4            0,3  23/09/2022  16/09/2022   Julho-2022
# 5           0,37  14/03/2023  28/02/2023    Fevereiro
# 6           0,07  07/03/2023  28/02/2023    FEVEREIRO
# 7           0,04  07/03/2023  28/02/2023    FEVEREIRO
# 8            NaN         NaN         NaN          NaN
# 9   14,792522495  28/09/2022  16/09/2022  Agosto-2022
# 10           NaN         NaN         NaN          NaN
# 11           NaN         NaN         NaN          NaN
# 12           NaN         NaN         NaN          NaN
# 13   1,824279249  14/03/2023  28/02/2023    Fevereiro
# 14           NaN         NaN         NaN          NaN
# 15           NaN         NaN         NaN          NaN

# %%
# CLEANING
combined = combined.drop('level_1', axis=1) #drop level_1

# RENAMING COLUMNS
combined.columns.values[0] = "Type"
combined.columns.values[1] = "ISIN"
combined.columns.values[2] = "Tipo de Amortizacao"
combined.columns.values[3] = "Isento IR"
combined.columns.values[4] = "Valor"
combined.columns.values[5] = "Data de Pagamento"
combined.columns.values[6] = "Data Base"
combined.columns.values[7] = "Periodo de Referencia"

#DELETE Código ISIN:
combined['ISIN'] = combined['ISIN'].str.replace('Código ISIN:','')

#DELETE ALL ROWS WHERE VALOR, PAGAMENTO, DATA BASE ARE NAN 
combined1 = combined.dropna(subset=['Valor', 'Data de Pagamento', 'Data Base'],how='all')
combined1.reset_index(drop=True)
# Out:
#           Type           ISIN Tipo de Amortizacao Isento IR         Valor  \
# 0   Rendimento   BRXPMLCTF000                 NaN       Sim          0,73
# 1   Rendimento   BRXPINCTF004             (Total)       Sim          0,62
# 2   Rendimento   BRFCFLCTF009           (Parcial)       Sim   0,874307201
# 3   Rendimento   BRBPMLCTF006                 NaN       Sim           0,3
# 4   Rendimento   BRRDPDCTF008                 NaN       Sim          0,37
# 5   Rendimento   BRARRICTF009                 NaN       Sim          0,07
# 6   Rendimento   BRARRIR12M19                 NaN       Sim          0,04
# 7  Amortizacao   BRIBFFCTF007                 NaN       NaN  14,792522495
# 8  Amortizacao   BRRDPDCTF008                 NaN       NaN   1,824279249
#
#   Data de Pagamento   Data Base Periodo de Referencia
# 0        23/09/2022  16/09/2022           Agosto-2022
# 1        23/09/2022  16/09/2022            31/08/2022
# 2        23/09/2022  16/09/2022           Agosto-2022
# 3        23/09/2022  16/09/2022            Julho-2022
# 4        14/03/2023  28/02/2023             Fevereiro
# 5        07/03/2023  28/02/2023             FEVEREIRO
# 6        07/03/2023  28/02/2023             FEVEREIRO
# 7        28/09/2022  16/09/2022           Agosto-2022
# 8        14/03/2023  28/02/2023             Fevereiro

# %%
# INSERTING NEW COLUMNS 

# VALUE MARKER 
combined1.insert(loc=3, column='Value Marker', value=['' for i in range(combined1.shape[0])])
combined1

#TAX MARKER
combined1.insert(loc=5, column='Tax Marker', value=['' for i in range(combined1.shape[0])])
combined1['Tax Marker'] = np.where(combined1['Isento IR']=='Sim', 'SF', '')

#TAX VALUE
combined1.insert(loc=6, column='Tax Value', value=['' for i in range(combined1.shape[0])])
combined1['Tax Value'] = np.where(combined1['Isento IR']=='Sim', '0%', '')


# EX DATE 
combined1.insert(loc=9, column='Ex Date', value=['' for i in range(combined1.shape[0])])

#SOURCE CODE
combined1.insert(loc=12, column='Source Code', value=['SE29' for i in range(combined1.shape[0])])
combined1

#SOURCE DATE
combined1.insert(loc=13, column='Source Date', value=['' for i in range(combined1.shape[0])])


#SOURCE TIME
combined1.insert(loc=14, column='Source Time', value=['' for i in range(combined1.shape[0])])
combined1
# Out:
# <ipython-input-46-5517dd529759>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   combined1['Tax Marker'] = np.where(combined1['Isento IR']=='Sim', 'SF', '')
# <ipython-input-46-5517dd529759>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   combined1['Tax Value'] = np.where(combined1['Isento IR']=='Sim', '0%', '')
#            Type           ISIN Tipo de Amortizacao Value Marker Isento IR  \
# 0    Rendimento   BRXPMLCTF000                 NaN                    Sim
# 2    Rendimento   BRXPINCTF004             (Total)                    Sim
# 3    Rendimento   BRFCFLCTF009           (Parcial)                    Sim
# 4    Rendimento   BRBPMLCTF006                 NaN                    Sim
# 5    Rendimento   BRRDPDCTF008                 NaN                    Sim
# 6    Rendimento   BRARRICTF009                 NaN                    Sim
# 7    Rendimento   BRARRIR12M19                 NaN                    Sim
# 9   Amortizacao   BRIBFFCTF007                 NaN                    NaN
# 13  Amortizacao   BRRDPDCTF008                 NaN                    NaN
#
#    Tax Marker Tax Value         Valor Data de Pagamento Ex Date   Data Base  \
# 0          SF        0%          0,73        23/09/2022          16/09/2022
# 2          SF        0%          0,62        23/09/2022          16/09/2022
# 3          SF        0%   0,874307201        23/09/2022          16/09/2022
# 4          SF        0%           0,3        23/09/2022          16/09/2022
# 5          SF        0%          0,37        14/03/2023          28/02/2023
# 6          SF        0%          0,07        07/03/2023          28/02/2023
# 7          SF        0%          0,04        07/03/2023          28/02/2023
# 9                        14,792522495        28/09/2022          16/09/2022
# 13                        1,824279249        14/03/2023          28/02/2023
#
#    Periodo de Referencia Source Code Source Date Source Time
# 0            Agosto-2022        SE29
# 2             31/08/2022        SE29
# 3            Agosto-2022        SE29
# 4             Julho-2022        SE29
# 5              Fevereiro        SE29
# 6              FEVEREIRO        SE29
# 7              FEVEREIRO        SE29
# 9            Agosto-2022        SE29
# 13             Fevereiro        SE29
